# %%
from mediabyte import omm

# %% [markdown]
# ## Playback

# %% [markdown]
# #### Browser and VLC Playback

# %% [markdown]
# Yota, Cue and Sample objects can be viewed in a browser tab with `play()`:

# %%
omm('y.R2ipPgrWypI.10m.11m').play()

# %% [markdown]
# or viewed in VLC with vlc():

# %%
omm('y.R2ipPgrWypI.10m.11m').vlc()

# %% [markdown]
# Remembering that `omm()` can parse YouTube URLs, we can use these directly:

# %%
omm('https://www.youtube.com/watch?v=dZLyfbSQPXI').vlc()

# %% [markdown]
# A Mixtape folds out into individual browser tabs with `Mixtape.open_tabs()`:

# %%
omm('y.R2ipPgrWypI.10m.11m.y.R2ipPgrWypI.13m.14m').open_tabs()

# %% [markdown]
# #### Mixtape HTML Player

# %% [markdown]
# A HTML/JavaScript Mixtape player can be written to file using `Mixtape.write_player_html(filename)`:

# %%
omm('y.R2ipPgrWypI.10m.11m.y.R2ipPgrWypI.13m.14m').write_player_html('mixtapeplayer.html')

# %% [markdown]
# Or the HTML accessed directly with `Mixtape.player()`:

# %%
omm('y.R2ipPgrWypI.10m.11m.y.R2ipPgrWypI.13m.14m').player()
# Out:
# '<iframe width="360" height="216" title="MySample" src="https://www.youtube.com/embed/R2ipPgrWypI?start=600&end=660&rel=0&autoplay=0&enablejsapi=1" frameborder=0 allowfullscreen></iframe> <iframe width="360" height="216" title="MySample" src="https://www.youtube.com/embed/R2ipPgrWypI?start=780&end=840&rel=0&autoplay=0&enablejsapi=1" frameborder=0 allowfullscreen></iframe> <script src="https://www.youtube.com/iframe_api"></script><script>function onYouTubeIframeAPIReady() { window.yotasamples = {}; let i = 0;  for (let ifrm of document.getElementsByTagName("iframe")) {       ifrm.id = "sample" + i;      ifrm.yotaidx = i;      window.yotasamples[i] = new YT.Player(ifrm.id, {events: {"onStateChange": playerStateChange}});        i++;  }}  function playerStateChange(event) {    console.log(event.data);    switch(event.data) {        case 0:            let myidx = event.target.getIframe().yotaidx;            event.target.getIframe().classList.remove("current");if (window.yotasamples[myidx
# ...

# %%
# sadly for this demo, HTML doesn't render in GitHub notebooks
# please follow the link below to view example in Colaboratory Notebook
# using Firefox

# %% [markdown]
# [YouTube search to mixtape player example](https://colab.research.google.com/drive/1FbEf9-8O3QbynTL_-9yuTawqWKXrIeEp)

# %% [markdown]
# #### Yota, Cue and Sample Iframe Player

# %% [markdown]
# Sample, Cue and Yota objecs also have an `.iframe()` method returning a HTML YouTube embedded player:

# %%
omm('y.R2ipPgrWypI.10m').iframe()
# Out:
# '<center><iframe width="360" height="216" title="MyCue" src="https://www.youtube.com/embed/R2ipPgrWypI?start=600&rel=0&autoplay=1" frameborder=0 allowfullscreen></iframe></center>'
